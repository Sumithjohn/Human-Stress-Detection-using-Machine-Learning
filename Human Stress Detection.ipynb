# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Smile\Downloads\python\sristi\SaYoPillow.csv")
df
# Out:
#          sr      rr       t      lm      bo     rem   sr.1     hr  sl
# 0    93.800  25.680  91.840  16.600  89.840   99.60  1.840  74.20   3
# 1    91.640  25.104  91.552  15.880  89.552   98.88  1.552  72.76   3
# 2    60.000  20.000  96.000  10.000  95.000   85.00  7.000  60.00   1
# 3    85.760  23.536  90.768  13.920  88.768   96.92  0.768  68.84   3
# 4    48.120  17.248  97.872   6.496  96.248   72.48  8.248  53.12   0
# ..      ...     ...     ...     ...     ...     ...    ...    ...  ..
# 625  69.600  20.960  92.960  10.960  90.960   89.80  3.440  62.40   2
# 626  48.440  17.376  98.064   6.752  96.376   73.76  8.376  53.44   0
# 627  97.504  27.504  86.880  17.752  84.256  101.88  0.000  78.76   4
# 628  58.640  19.728  95.728   9.728  94.592   84.32  6.728  59.32   1
# 629  73.920  21.392  93.392  11.392  91.392   91.96  4.088  63.48   2
#
# [630 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# sr      0
# rr      0
# t       0
# lm      0
# bo      0
# rem     0
# sr.1    0
# hr      0
# sl      0
# dtype: int64

# %%
df['sl'].unique()
# Out:
# array([3, 1, 0, 2, 4], dtype=int64)

# %%
df.describe()
# Out:
#                sr          rr          t          lm          bo         rem  \
# count  630.000000  630.000000  630.00000  630.000000  630.000000  630.000000
# mean    71.600000   21.800000   92.80000   11.700000   90.900000   88.500000
# std     19.372833    3.966111    3.52969    4.299629    3.902483   11.893747
# min     45.000000   16.000000   85.00000    4.000000   82.000000   60.000000
# 25%     52.500000   18.500000   90.50000    8.500000   88.500000   81.250000
# 50%     70.000000   21.000000   93.00000   11.000000   91.000000   90.000000
# 75%     91.250000   25.000000   95.50000   15.750000   94.250000   98.750000
# max    100.000000   30.000000   99.00000   19.000000   97.000000  105.000000
#
#              sr.1          hr          sl
# count  630.000000  630.000000  630.000000
# mean     3.700000   64.500000    2.000000
# std      3.054572    9.915277    1.415337
# min      0.000000   50.000000    0.000000
# 25%      0.500000   56.250000    1.000000
# ...

# %%
df.columns
# Out:
# Index(['sr', 'rr', 't', 'lm', 'bo', 'rem', 'sr.1', 'hr', 'sl'], dtype='object')

# %%
df.rename(columns={'sr': 'snoring range', 'rr': 'respiration rate','t':'body temperature','lm': 'limb movement rate ','bo':'blood oxygen level','rem':'eye movement','sr.1':'number of hours of sleep','hr':'heart rate','sl':'Stress Levels'}, inplace=True)

# %%
df
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 0           93.800            25.680            91.840               16.600
# 1           91.640            25.104            91.552               15.880
# 2           60.000            20.000            96.000               10.000
# 3           85.760            23.536            90.768               13.920
# 4           48.120            17.248            97.872                6.496
# ..             ...               ...               ...                  ...
# 625         69.600            20.960            92.960               10.960
# 626         48.440            17.376            98.064                6.752
# 627         97.504            27.504            86.880               17.752
# 628         58.640            19.728            95.728                9.728
# 629         73.920            21.392            93.392               11.392
#
# ...

# %%
df0=df[df['Stress Levels']==0]
df0
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 4            48.12            17.248            97.872                6.496
# 6            47.00            16.800            97.200                5.600
# 7            50.00            18.000            99.000                8.000
# 8            45.28            16.112            96.168                4.224
# 12           48.60            17.440            98.160                6.880
# ..             ...               ...               ...                  ...
# 597          45.64            16.256            96.384                4.512
# 604          48.32            17.328            97.992                6.656
# 618          48.40            17.360            98.040                6.720
# 619          46.08            16.432            96.648                4.864
# 626          48.44            17.376            98.064                6.752
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.histplot(df['heart rate'], kde=True)
plt.title('Heart Rate')
plt.xlabel('Heart Rate')
plt.ylabel('Frequency')
plt.show()

# %%
df1=df[df['Stress Levels']==1]
df1
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 2            60.00            20.000            96.000               10.000
# 5            56.88            19.376            95.376                9.376
# 9            55.52            19.104            95.104                9.104
# 11           59.28            19.856            95.856                9.856
# 15           52.32            18.464            94.464                8.464
# ..             ...               ...               ...                  ...
# 609          54.64            18.928            94.928                8.928
# 616          59.04            19.808            95.808                9.808
# 621          53.20            18.640            94.640                8.640
# 624          58.80            19.760            95.760                9.760
# 628          58.64            19.728            95.728                9.728
#
# ...

# %%
df2=df[df['Stress Levels']==2]
df2
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 10           73.44            21.344            93.344               11.344
# 19           63.68            20.368            92.368               10.368
# 20           77.60            21.760            93.760               11.760
# 21           77.28            21.728            93.728               11.728
# 22           69.76            20.976            92.976               10.976
# ..             ...               ...               ...                  ...
# 614          62.40            20.240            92.240               10.240
# 617          71.68            21.168            93.168               11.168
# 622          65.44            20.544            92.544               10.544
# 625          69.60            20.960            92.960               10.960
# 629          73.92            21.392            93.392               11.392
#
# ...

# %%
df3=df[df['Stress Levels']==3]
df3
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 0            93.80            25.680            91.840                16.60
# 1            91.64            25.104            91.552                15.88
# 3            85.76            23.536            90.768                13.92
# 14           87.80            24.080            91.040                14.60
# 17           86.24            23.664            90.832                14.08
# ..             ...               ...               ...                  ...
# 600          93.56            25.616            91.808                16.52
# 605          94.04            25.744            91.872                16.68
# 610          93.68            25.648            91.824                16.56
# 612          88.88            24.368            91.184                14.96
# 615          82.88            22.768            90.384                12.96
#
# ...

# %%
df4=df[df['Stress Levels']==4]
df4
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 13          96.288            26.288             85.36               17.144
# 31          96.256            26.256             85.32               17.128
# 33          99.904            29.904             89.88               18.952
# 37          98.528            28.528             88.16               18.264
# 39          98.720            28.720             88.40               18.360
# ..             ...               ...               ...                  ...
# 606         97.760            27.760             87.20               17.880
# 611         98.592            28.592             88.24               18.296
# 620         97.024            27.024             86.28               17.512
# 623         98.144            28.144             87.68               18.072
# 627         97.504            27.504             86.88               17.752
#
# ...

# %%
x=df.drop(['Stress Levels'],axis=1)
x
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 0           93.800            25.680            91.840               16.600
# 1           91.640            25.104            91.552               15.880
# 2           60.000            20.000            96.000               10.000
# 3           85.760            23.536            90.768               13.920
# 4           48.120            17.248            97.872                6.496
# ..             ...               ...               ...                  ...
# 625         69.600            20.960            92.960               10.960
# 626         48.440            17.376            98.064                6.752
# 627         97.504            27.504            86.880               17.752
# 628         58.640            19.728            95.728                9.728
# 629         73.920            21.392            93.392               11.392
#
# ...

# %%
y=df['Stress Levels']
y
# Out:
# 0      3
# 1      3
# 2      1
# 3      3
# 4      0
#       ..
# 625    2
# 626    0
# 627    4
# 628    1
# 629    2
# Name: Stress Levels, Length: 630, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
X_train
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 80          50.640            18.128            94.128                8.128
# 141         81.440            22.384            90.192               12.480
# 620         97.024            27.024            86.280               17.512
# 277         89.480            24.528            91.264               15.160
# 418         81.800            22.480            90.240               12.600
# ..             ...               ...               ...                  ...
# 185         67.040            20.704            92.704               10.704
# 48          56.720            19.344            95.344                9.344
# 531         47.600            17.040            97.560                6.080
# 340         45.600            16.240            96.360                4.480
# 570         99.840            29.840            89.800               18.920
#
# ...

# %%
y_train
# Out:
# 80     1
# 141    3
# 620    4
# 277    3
# 418    3
#       ..
# 185    2
# 48     1
# 531    0
# 340    0
# 570    4
# Name: Stress Levels, Length: 504, dtype: int64

# %%
X_test
# Out:
#      snoring range  respiration rate  body temperature  limb movement rate   \
# 487         82.160            22.576            90.288               12.720
# 74          48.680            17.472            98.208                6.944
# 490         63.840            20.384            92.384               10.384
# 15          52.320            18.464            94.464                8.464
# 454         55.440            19.088            95.088                9.088
# ..             ...               ...               ...                  ...
# 370         97.472            27.472            86.840               17.736
# 458         99.584            29.584            89.480               18.792
# 118         49.520            17.808            98.712                7.616
# 581         72.000            21.200            93.200               11.200
# 546         64.480            20.448            92.448               10.448
#
# ...

# %%
y_test
# Out:
# 487    3
# 74     0
# 490    2
# 15     1
# 454    1
#       ..
# 370    4
# 458    4
# 118    0
# 581    2
# 546    2
# Name: Stress Levels, Length: 126, dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
l_model=LogisticRegression()

# %%
l_model.fit(X_train,y_train)
# Out:
# C:\Users\Smile\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=l_model.predict(X_test)
y_pred
# Out:
# array([3, 0, 2, 1, 1, 1, 3, 0, 0, 3, 4, 0, 3, 2, 0, 1, 0, 3, 4, 0, 3, 3,
#        2, 1, 2, 2, 3, 0, 1, 0, 0, 2, 4, 2, 1, 3, 2, 0, 0, 4, 4, 4, 1, 1,
#        4, 2, 3, 3, 0, 0, 1, 2, 3, 0, 0, 0, 4, 1, 3, 4, 4, 1, 1, 4, 1, 4,
#        1, 0, 0, 3, 1, 1, 2, 2, 4, 2, 1, 3, 3, 0, 4, 0, 3, 4, 0, 3, 2, 0,
#        4, 0, 1, 3, 1, 3, 3, 3, 1, 3, 0, 2, 2, 4, 2, 1, 4, 0, 3, 3, 1, 3,
#        2, 3, 3, 3, 0, 1, 0, 1, 2, 4, 4, 4, 4, 0, 2, 2], dtype=int64)

# %%
accuracy=l_model.score(X_test,y_test)
print('L_accuracy :',accuracy)
# Out:
# L_accuracy : 1.0

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[29,  0,  0,  0,  0],
#        [ 0, 25,  0,  0,  0],
#        [ 0,  0, 21,  0,  0],
#        [ 0,  0,  0, 29,  0],
#        [ 0,  0,  0,  0, 22]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.title('Confusion Matrix for LogisticRegression ')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        25
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        29
#            4       1.00      1.00      1.00        22
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=100)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy1=rf_model.score(X_test,y_test)
print('Rf_accuracy :',accuracy1)
# Out:
# Rf_accuracy : 0.9841269841269841

# %%
y_pred_rf=rf_model.predict(X_test)
y_pred_rf
# Out:
# array([3, 0, 2, 1, 1, 1, 3, 0, 0, 3, 4, 0, 3, 2, 0, 1, 0, 3, 4, 0, 3, 3,
#        2, 1, 2, 2, 3, 0, 1, 0, 0, 2, 4, 2, 1, 3, 2, 0, 0, 4, 4, 4, 1, 1,
#        4, 2, 3, 3, 0, 0, 1, 2, 3, 0, 0, 0, 4, 1, 3, 4, 4, 1, 1, 4, 1, 4,
#        1, 0, 0, 3, 0, 1, 1, 2, 4, 2, 1, 3, 3, 0, 4, 0, 3, 4, 0, 3, 2, 0,
#        4, 0, 1, 3, 1, 3, 3, 3, 1, 3, 0, 2, 2, 4, 2, 1, 4, 0, 3, 3, 1, 3,
#        2, 3, 3, 3, 0, 1, 0, 1, 2, 4, 4, 4, 4, 0, 2, 2], dtype=int64)

# %%
rf_cm=confusion_matrix(y_test,y_pred_rf)
rf_cm
# Out:
# array([[29,  0,  0,  0,  0],
#        [ 1, 24,  0,  0,  0],
#        [ 0,  1, 20,  0,  0],
#        [ 0,  0,  0, 29,  0],
#        [ 0,  0,  0,  0, 22]], dtype=int64)

# %%
sns.heatmap(rf_cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.title('Confusion Matrix for Random Forest ')
plt.show()

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        29
#            1       0.96      0.96      0.96        25
#            2       1.00      0.95      0.98        21
#            3       1.00      1.00      1.00        29
#            4       1.00      1.00      1.00        22
#
#     accuracy                           0.98       126
#    macro avg       0.99      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126

# %% [markdown]
# # KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier(n_neighbors=10)

# %%
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn_model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_pred_k=knn_model.predict(X_test)
y_pred_k
# Out:
# array([3, 0, 2, 1, 1, 1, 3, 0, 0, 3, 4, 0, 3, 2, 0, 1, 0, 3, 4, 0, 3, 3,
#        2, 1, 2, 2, 3, 0, 1, 0, 0, 2, 4, 2, 1, 3, 2, 0, 0, 4, 4, 4, 1, 1,
#        4, 2, 3, 3, 0, 0, 1, 2, 3, 0, 0, 0, 4, 1, 3, 4, 4, 1, 1, 4, 1, 4,
#        1, 0, 0, 3, 1, 1, 2, 2, 4, 2, 1, 3, 3, 0, 4, 0, 3, 4, 0, 3, 2, 0,
#        4, 0, 1, 3, 1, 3, 3, 3, 1, 3, 0, 2, 2, 4, 2, 1, 4, 0, 3, 3, 1, 3,
#        2, 3, 3, 3, 0, 1, 0, 1, 2, 4, 4, 4, 4, 0, 2, 2], dtype=int64)

# %%
knn_cm=confusion_matrix(y_test,y_pred_k)
knn_cm
# Out:
# array([[29,  0,  0,  0,  0],
#        [ 0, 25,  0,  0,  0],
#        [ 0,  0, 21,  0,  0],
#        [ 0,  0,  0, 29,  0],
#        [ 0,  0,  0,  0, 22]], dtype=int64)

# %%
sns.heatmap(knn_cm,annot=True)
plt.xlabel('predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix for knn')
plt.show()

# %%
print(classification_report(y_test,y_pred_k))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        25
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        29
#            4       1.00      1.00      1.00        22
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126

# %% [markdown]
# # xgboost

# %%
from xgboost import XGBClassifier

# %%
x_model=XGBClassifier()

# %%
x_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
x_model.score(X_test,y_test)
# Out:
# 0.9841269841269841

# %%
y_pred_xg=x_model.predict(X_test)
y_pred_xg
# Out:
# array([3, 0, 2, 1, 1, 1, 3, 0, 0, 3, 4, 0, 3, 2, 0, 1, 0, 3, 4, 0, 3, 3,
#        2, 1, 2, 2, 3, 0, 1, 0, 0, 2, 4, 2, 1, 3, 2, 0, 0, 4, 4, 4, 1, 1,
#        4, 2, 3, 3, 0, 0, 1, 2, 3, 0, 0, 0, 4, 1, 3, 4, 4, 1, 1, 4, 1, 4,
#        1, 0, 0, 3, 0, 1, 3, 2, 4, 2, 1, 3, 3, 0, 4, 0, 3, 4, 0, 3, 2, 0,
#        4, 0, 1, 3, 1, 3, 3, 3, 1, 3, 0, 2, 2, 4, 2, 1, 4, 0, 3, 3, 1, 3,
#        2, 3, 3, 3, 0, 1, 0, 1, 2, 4, 4, 4, 4, 0, 2, 2], dtype=int64)

# %%
xg_cm=confusion_matrix(y_test,y_pred_xg)
xg_cm
# Out:
# array([[29,  0,  0,  0,  0],
#        [ 1, 24,  0,  0,  0],
#        [ 0,  0, 20,  1,  0],
#        [ 0,  0,  0, 29,  0],
#        [ 0,  0,  0,  0, 22]], dtype=int64)

# %%
sns.heatmap(xg_cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.title('Confusion Matrix for XGBoost ')
plt.show()

# %%
print(classification_report(y_test, y_pred_xg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        29
#            1       1.00      0.96      0.98        25
#            2       1.00      0.95      0.98        21
#            3       0.97      1.00      0.98        29
#            4       1.00      1.00      1.00        22
#
#     accuracy                           0.98       126
#    macro avg       0.99      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126

# %%
import pickle

# %%
with open("stress_model.pkl", "wb") as model_file:
    pickle.dump(rf_model, model_file)
